# %% [markdown]
# # Minigrid navigation stable baseline

# %%
import sys

sys.path.append("..")

import numpy as np
import gym

import torch
import torch.nn as nn

import train_worker
from environments import NavigationGoalWrapper

from stable_baselines3 import DQN
from rllr_stable_baselines3 import GoalStateExtenderWrapper, ExtendedStateFeatureExtractor, StateExtenderWrapper

# %%
worker_env_config = {
        "env_type": "gym_minigrid",
        "env_task": "MiniGrid-Empty",
        "grid_size": 8,
        "action_size": 3,
        "rgb_image": False,
        "goal_achieving_criterion": "position",
        "goal_type": "random",
        "video_path": "outputs/video/"
    }

worker_env = train_worker.gen_navigation_env(worker_env_config)
worker_env = GoalStateExtenderWrapper(worker_env)

policy_kwargs = dict(
    features_extractor_class=ExtendedStateFeatureExtractor,
    features_extractor_kwargs=dict(features_dim=64, hidden=128),
    net_arch=[128, 128]
)

dqn_kwargs = {
    "learning_rate": 1e-3,
    "buffer_size": int(1e5),
    "batch_size": 128,
    "learning_starts": 1000,
    "exploration_fraction": 0.995,
    "gamma": 0.9,
    "tau": 0.999,
    "seed": 42,
    "policy_kwargs": policy_kwargs,
    "verbose": 1
}

worker = DQN("MlpPolicy", worker_env, **dqn_kwargs)

worker.learn(10000, log_interval=10)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 147      |
# |    ep_rew_mean      | -13.8    |
# |    exploration rate | 0.86     |
# | time/               |          |
# |    episodes         | 10       |
# |    fps              | 1057     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 1469     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000402 |
# |    n_updates        | 117      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | -11.4    |
# |    exploration rate | 0.765    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 768      |
# |    time_elapsed     | 3        |
# |    total timesteps  | 2466     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0103   |
# |    n_updates        | 366      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -10.6    |
# |    exploration rate | 0.669    |
# | time/               |          |
# |    episodes         | 30       |
# |    fps              | 684      |
# |    time_elapsed     | 5        |
# |    total timesteps  | 3467     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000175 |
# |    n_updates        | 616      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | -11.6    |
# |    exploration rate | 0.524    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 619      |
# |    time_elapsed     | 8        |
# |    total timesteps  | 4981     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00421  |
# |    n_updates        | 995      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | -11      |
# |    exploration rate | 0.434    |
# | time/               |          |
# |    episodes         | 50       |
# |    fps              | 590      |
# |    time_elapsed     | 10       |
# |    total timesteps  | 5931     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00199  |
# |    n_updates        | 1232     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 124      |
# |    ep_rew_mean      | -11.5    |
# |    exploration rate | 0.291    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 562      |
# |    time_elapsed     | 13       |
# |    total timesteps  | 7423     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00315  |
# |    n_updates        | 1605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | -12.2    |
# |    exploration rate | 0.131    |
# | time/               |          |
# |    episodes         | 70       |
# |    fps              | 530      |
# |    time_elapsed     | 17       |
# |    total timesteps  | 9099     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000581 |
# |    n_updates        | 2024     |
# ----------------------------------

# %%
master_env_config = {
    "env_type": "gym_minigrid",
    "env_task": "MiniGrid-Empty",
    "grid_size": 8,
    "action_size": 3,
    "rgb_image": False,
    "video_path": "outputs/video/"
}

master_env = minigrid_envs.gen_wrapped_env(master_env_config)
master_env = StateExtenderWrapper(master_env)
worker.set_env(master_env)

for param in worker.policy.q_net.features_extractor.state_encoder.parameters():
    param.requires_gradient = False

for param in worker.policy.q_net.q_net.parameters():
    param.requires_gradient = False

worker.learn(30000, log_interval=10)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 236      |
# |    ep_rew_mean      | 0.109    |
# |    exploration rate | 0.925    |
# | time/               |          |
# |    episodes         | 10       |
# |    fps              | 770      |
# |    time_elapsed     | 3        |
# |    total timesteps  | 2363     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000483 |
# |    n_updates        | 2590     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | 0.23     |
# |    exploration rate | 0.87     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 660      |
# |    time_elapsed     | 6        |
# |    total timesteps  | 4096     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000351 |
# |    n_updates        | 3023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 0.262    |
# |    exploration rate | 0.812    |
# | time/               |          |
# |    episodes         | 30       |
# |    fps              | 621      |
# |    time_elapsed     | 9        |
# |    total timesteps  | 5898     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00199  |
# |    n_updates        | 3474     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 0.331    |
# |    exploration rate | 0.771    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 586      |
# |    time_elapsed     | 12       |
# |    total timesteps  | 7188     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0004   |
# |    n_updates        | 3796     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 0.36     |
# |    exploration rate | 0.726    |
# | time/               |          |
# |    episodes         | 50       |
# |    fps              | 547      |
# |    time_elapsed     | 15       |
# |    total timesteps  | 8620     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00054  |
# |    n_updates        | 4154     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 0.358    |
# |    exploration rate | 0.67     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 523      |
# |    time_elapsed     | 19       |
# |    total timesteps  | 10383    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00123  |
# |    n_updates        | 4595     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 0.347    |
# |    exploration rate | 0.609    |
# | time/               |          |
# |    episodes         | 70       |
# |    fps              | 496      |
# |    time_elapsed     | 24       |
# |    total timesteps  | 12281    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000845 |
# |    n_updates        | 5070     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 0.337    |
# |    exploration rate | 0.546    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 490      |
# |    time_elapsed     | 29       |
# |    total timesteps  | 14264    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000789 |
# |    n_updates        | 5565     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 0.336    |
# |    exploration rate | 0.489    |
# | time/               |          |
# |    episodes         | 90       |
# |    fps              | 483      |
# |    time_elapsed     | 33       |
# |    total timesteps  | 16043    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000308 |
# |    n_updates        | 6010     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 0.316    |
# |    exploration rate | 0.418    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 471      |
# |    time_elapsed     | 38       |
# |    total timesteps  | 18295    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000277 |
# |    n_updates        | 6573     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 0.315    |
# |    exploration rate | 0.343    |
# | time/               |          |
# |    episodes         | 110      |
# |    fps              | 458      |
# |    time_elapsed     | 45       |
# |    total timesteps  | 20654    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000968 |
# |    n_updates        | 7163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 0.306    |
# |    exploration rate | 0.279    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 454      |
# |    time_elapsed     | 49       |
# |    total timesteps  | 22655    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000558 |
# |    n_updates        | 7663     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 0.305    |
# |    exploration rate | 0.221    |
# | time/               |          |
# |    episodes         | 130      |
# |    fps              | 452      |
# |    time_elapsed     | 54       |
# |    total timesteps  | 24490    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00302  |
# |    n_updates        | 8122     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 0.267    |
# |    exploration rate | 0.151    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 449      |
# |    time_elapsed     | 59       |
# |    total timesteps  | 26689    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000109 |
# |    n_updates        | 8672     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | 0.227    |
# |    exploration rate | 0.0746   |
# | time/               |          |
# |    episodes         | 150      |
# |    fps              | 442      |
# |    time_elapsed     | 65       |
# |    total timesteps  | 29077    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000221 |
# |    n_updates        | 9269     |
# ----------------------------------
