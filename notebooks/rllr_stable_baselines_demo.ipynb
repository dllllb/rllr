# %% [markdown]
# # Minigrid navigation stable baseline

# %%
import sys

sys.path.append("..")

import master_worker_dqn_stable_baselines3, master_worker_ppo_stable_baselines3

# %% [markdown]
# # DQN

# %%
agent_dqn = master_worker_dqn_stable_baselines3.train_1st_stage()
# Out:
# /opt/anaconda3/envs/rllr/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 112      |
# |    ep_rew_mean      | -10.1    |
# |    exploration rate | 0.989    |
# | time/               |          |
# |    episodes         | 10       |
# |    fps              | 1421     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1119     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000106 |
# |    n_updates        | 29       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# ...

# %%
master_worker_dqn_stable_baselines3.train_2nd_stage(agent_dqn)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 206      |
# |    ep_rew_mean      | 0.226    |
# |    exploration rate | 0.98     |
# | time/               |          |
# |    episodes         | 10       |
# |    fps              | 838      |
# |    time_elapsed     | 2        |
# |    total timesteps  | 2059     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00472  |
# |    n_updates        | 25014    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 0.269    |
# |    exploration rate | 0.963    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 673      |
# |    time_elapsed     | 5        |
# ...

# %% [markdown]
# # PPO

# %%
agent_ppo = master_worker_ppo_stable_baselines3.train_1st_stage()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 139      |
# |    ep_rew_mean      | -13      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    fps              | 972      |
# |    iterations       | 1        |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2048     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0045   |
# |    n_updates        | 99500    |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | -10.8       |
# | time/                   |             |
# |    fps                  | 792         |
# |    iterations           | 2           |
# ...

# %%
master_worker_ppo_stable_baselines3.train_2nd_stage(agent_ppo)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.8        |
# |    ep_rew_mean          | 0.92        |
# | time/                   |             |
# |    fps                  | 695         |
# |    iterations           | 10          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.096195646 |
# |    clip_fraction        | 0.407       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0519     |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0448     |
# |    value_loss           | 0.0169      |
# ...
